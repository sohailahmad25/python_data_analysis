# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_iris = sns.load_dataset('iris')

# %%
df_iris.sample(20)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 94            5.6          2.7           4.2          1.3  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 50            7.0          3.2           4.7          1.4  versicolor
# 70            5.9          3.2           4.8          1.8  versicolor
# 129           7.2          3.0           5.8          1.6   virginica
# 41            4.5          2.3           1.3          0.3      setosa
# 132           6.4          2.8           5.6          2.2   virginica
# 149           5.9          3.0           5.1          1.8   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 28            5.2          3.4           1.4          0.2      setosa
# 107           7.3          2.9           6.3          1.8   virginica
# ...

# %%
dfex = pd.DataFrame({
    'numbers': np.arange(1,101),
    'statistics': np.random.normal(0,1,100)
})

# %%
dfex
# Out:
#     numbers  statistics
# 0         1    0.360921
# 1         2    1.747413
# 2         3   -0.813011
# 3         4    0.609130
# 4         5   -1.918509
# 5         6   -1.800134
# 6         7    1.192870
# 7         8   -0.686412
# 8         9   -1.397442
# 9        10    1.639151
# 10       11   -0.474999
# 11       12    0.615194
# 12       13    0.832402
# 13       14    0.303832
# 14       15    1.085850
# 15       16    0.748909
# 16       17    0.915699
# 17       18    2.320615
# 18       19   -0.318827
# 19       20    0.412154
# 20       21   -0.420806
# 21       22   -0.107113
# 22       23    0.622006
# 23       24   -0.693088
# 24       25   -1.085046
# 25       26   -0.220677
# 26       27   -0.163169
# 27       28   -2.008157
# 28       29   -0.262779
# 29       30   -1.827588
# 30       31    2.904423
# 31       32    0.186879
# 32       33   -2.164935
# 33       34   -2.089815
# 34       35    0.846951
# 35       36   -0.252504
# 36       37    1.165900
# ...

# %%
sns.set_style("whitegrid")
graph_dfex= sns.lmplot(
    x= 'numbers',
    y= 'statistics',
    data= dfex,
    aspect=2
)

# %%
print("show")
# Out:
# Running cells with 'sohailenvtest' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n sohailenvtest ipykernel --update-deps --force-reinstall'
