# %%
import pandas as pd

# %%
pakpop_df = pd.read_csv('sub-division_population_of_pakistan.csv')

# %%
pakpop_df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# pip install openpyxl

# %% [markdown]
# ## Reading a specific sheet of an excel file
# pd.read_excel('filepath_with_extension', sheet_name='Sheet1')

# %%
pakpop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
pakpop_df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
pakpop_description = pakpop_df.describe()   #made another dataframe by the name pakpop_description, all the decribed things will go to this DF

# %%
pakpop_description['AREA (sq.km)']['max']  # I took "Area (sq.km)" col, and took row "max" so it is kind of key value thing to access a specific value in a specific col
# Out:
# 18374.0

# %%
pakpop_df.shape[0]-1     #as only .shape returns a tuple of row,col   to extract only number of rows we will use conventional method, []  but indices will be one less than actual number of rows
# Out:
# 527

# %% [markdown]
# ---
# ## Index-based selection
# ---

# %% [markdown]
# Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.
#
# This means that it's marginally easier to retrieve rows, and marginally harder to get retrieve columns. To get a column with iloc, we can do the following:

# %%
pakpop_df.iloc[pakpop_df.shape[0]-1, :3]         #this means, select first 3 cols for the row 527  (pakpop_df.shape[0]-1  means row num last)
# Out:
# PROVINCE                     KPK/FATA
# DIVISION    DERA ISMAIL KHAN DIVISION
# DISTRICT    SOUTH WAZIRISTAN DISTRICT
# Name: 527, dtype: object

# %%
pakpop_df.iloc[:3,0]  #first 3 rows(index up to 2) and first col which is 0
# Out:
# 0    PUNJAB
# 1    PUNJAB
# 2    PUNJAB
# Name: PROVINCE, dtype: object

# %%
pakpop_df.iloc[:5, :4]  #means show 5 rows from index 1 to index 4 and  col 1 to 4
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL

# %% [markdown]
# We can range make it a range (as already looking like a range :  )

# %%
pakpop_df.iloc[3:9, :4]   #show rows from index 3 upto 9 but 9 not included, Same can be done with columns to select a range
# Out:
#   PROVINCE             DIVISION               DISTRICT  \
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 5   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 6   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 7   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 8   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
#
#                SUB DIVISION
# 3         HAROONABAD TEHSIL
# 4        MINCHINABAD TEHSIL
# 5      AHMADPUR EAST TEHSIL
# 6    BAHAWALPUR CITY TEHSIL
# 7  BAHAWALPUR SADDAR TEHSIL
# 8           HASILPUR TEHSIL

# %% [markdown]
# ## It's also possible to pass a list:

# %%
pakpop_df.iloc[[4,5,7], :4]
# Out:
#   PROVINCE             DIVISION               DISTRICT  \
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 5   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 7   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
#
#                SUB DIVISION
# 4        MINCHINABAD TEHSIL
# 5      AHMADPUR EAST TEHSIL
# 7  BAHAWALPUR SADDAR TEHSIL

# %% [markdown]
# Finally, it's worth knowing that negative numbers can be used in selection. This will start counting forwards from the end of the values. So for example here are the last five elements of the dataset.

# %%
pakpop_df.iloc[-5:]  # [5] without : will show the single row number 527-5= 522.  Also it will show all the cols as it is equivalent to iloc[-5:, : ]
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 523   SARAROGHA TEHSIL         813.0              98180         51479
# 524    SERWEKAI TEHSIL         398.0              54540         28695
# 525      TIARZA TEHSIL         734.0              45156         23649
# 526  TOI KHULLA TEHSIL         567.0              50413         27462
# 527        WANA TEHSIL        2315.0             153156         81342
#
#      FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  \
# 523           46694                    7             110.25  ...
# ...

# %%
pakpop_df.iloc[-5]    #only select row number 522
# Out:
# PROVINCE                                       KPK/FATA
# DIVISION                      DERA ISMAIL KHAN DIVISION
# DISTRICT                      SOUTH WAZIRISTAN DISTRICT
# SUB DIVISION                           SARAROGHA TEHSIL
# AREA (sq.km)                                      813.0
# ALL SEXES (RURAL)                                 98180
# MALE (RURAL)                                      51479
# FEMALE (RURAL)                                    46694
# TRANSGENDER (RURAL)                                   7
# SEX RATIO (RURAL)                                110.25
# AVG HOUSEHOLD SIZE (RURAL)                         7.57
# POPULATION 1998 (RURAL)                           72063
# ANNUAL GROWTH RATE (RURAL)                         1.64
# ALL SEXES (URBAN)                                     0
# MALE (URBAN)                                          0
# FEMALE (URBAN)                                        0
# TRANSGENDER (URBAN)                                   0
# ...

# %% [markdown]
# ------
#
# ## Label-based selection
#
# -----
#
# The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters.
#
# For example, to get the first entry in pakpop_df, we would now do the following:

# %%
pakpop_df.loc[0,'FEMALE (RURAL)']  # it selected the row with index name = 0 and col name = 'FEMALE (RURAL)'
# Out:
# 302644

# %%
pakpop_df.iloc[0, 7]  # in iloc, we give it row index 0 and col index 7
# Out:
# 302644

# %% [markdown]
# iloc is conceptually simpler than loc because it ignores the dataset's indices. When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. loc, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead. For example, here's one operation that's much easier using loc:

# %%
pakpop_df.loc[0:10,['ALL SEXES (RURAL)', 'TRANSGENDER (RURAL)', 'POPULATION 1998 (RURAL)']]
# Out:
#     ALL SEXES (RURAL)  TRANSGENDER (RURAL)  POPULATION 1998 (RURAL)
# 0              619550                   42                   407768
# 1              540342                   54                   395983
# 2              361240                   44                   250959
# 3              382115                   29                   297343
# 4              452723                   39                   316593
# 5              902476                   62                   601406
# 6                   0                    0                    62916
# 7              467938                   51                   314428
# 8              340747                   10                   246218
# 9              221431                    3                   157049
# 10             564422                   49                   385770

# %% [markdown]
# Choosing between loc and iloc
# When choosing or transitioning between loc and iloc, there is one "gotcha" worth keeping in mind, which is that the two methods use slightly different indexing schemes.
#
# ***iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.***
#
# Why the change? Remember that loc can index any stdlib type: strings, for example. If we have a DataFrame with index values Apples, ..., Potatoes, ..., and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index df.loc['Apples':'Potatoes'] than it is to index something like df.loc['Apples', 'Potatoet'] (t coming after s in the alphabet).
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999].
#
# Otherwise, the semantics of using loc are the same as those for iloc.

# %% [markdown]
# ## Manipulating the index
# Label-based selection derives its power from the labels in the index. Critically, the index we use is mutable. We can manipulate the index in any way we see fit.
#
# The set_index() method can be used to do the job. Here is what happens when we set_index to the **Province** field:

# %%
pakpop_df.set_index("PROVINCE")  # will set the Province col as index . It is not inplace function though
# Out:
#                            DIVISION                   DISTRICT  \
# PROVINCE
# PUNJAB          BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# PUNJAB          BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# PUNJAB          BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# PUNJAB          BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# PUNJAB          BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ...                             ...                        ...
# KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#                  SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# PROVINCE
# PUNJAB    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %%
pakpop_df
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %% [markdown]
# ## Conditional selection
# So far we've been indexing various strides of data, using structural properties of the DataFrame itself. To do interesting things with the data, however, we often need to ask questions based on conditions.
#
# For example, suppose that we're interested specifically in KPK/FATA where .
#
# We can start by checking if each wine is Italian or not:

# %%
pakpop_df.PROVINCE == 'KPK/FATA'  #WILL give us only those records of Provice column where the record is KPK/FATA
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 523     True
# 524     True
# 525     True
# 526     True
# 527     True
# Name: PROVINCE, Length: 528, dtype: bool

# %%
#Now we will give to loc method as it is a label based selection.

pakpop_df.loc[pakpop_df.PROVINCE == 'KPK/FATA']  #will give us all the rows where in province col there is value KPK/FATA
# in the last it is shown 46 such records are there.
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 482  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 483  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 484  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 485  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 486  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 487  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 488  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 489  KPK/FATA             BANNU DIVISION          FR BANNU DISTRICT
# 490  KPK/FATA  DERA ISMAIL KHAN DIVISION       FR D.I.KHAN DISTRICT
# 491  KPK/FATA             KOHAT DIVISION          FR KOHAT DISTRICT
# 492  KPK/FATA             BANNU DIVISION   FR LAKKI MARWAT DISTRICT
# 493  KPK/FATA          PESHAWAR DIVISION       FR PESHAWAR DISTRICT
# 494  KPK/FATA          PESHAWAR DIVISION            KHYBER DISTRICT
# ...

# %%
pakpop_df.loc[pakpop_df.PROVINCE == 'KPK/FATA', :"ALL SEXES (RURAL)"] #cols upto "ALL SEXES (RURAL)" shown
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 482  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 483  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 484  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 485  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 486  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 487  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 488  KPK/FATA          MALAKAND DIVISION            BAJAUR DISTRICT
# 489  KPK/FATA             BANNU DIVISION          FR BANNU DISTRICT
# 490  KPK/FATA  DERA ISMAIL KHAN DIVISION       FR D.I.KHAN DISTRICT
# 491  KPK/FATA             KOHAT DIVISION          FR KOHAT DISTRICT
# 492  KPK/FATA             BANNU DIVISION   FR LAKKI MARWAT DISTRICT
# 493  KPK/FATA          PESHAWAR DIVISION       FR PESHAWAR DISTRICT
# 494  KPK/FATA          PESHAWAR DIVISION            KHYBER DISTRICT
# ...

# %%
# Double conditions

pakpop_df.loc[(pakpop_df.PROVINCE== 'KPK/FATA') & (pakpop_df.DIST) ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9336\702864646.py in ?()
#       1 # Double conditions
#       2
# ----> 3 pakpop_df.loc[(pakpop_df.PROVINCE== 'KPK/FATA') & (pakpop_df.DIST) ]
#
# c:\Users\admin\miniconda3\envs\dataanalysis\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DIST'
